# %%
# !wget https://raw.githubusercontent.com/pathwaytipsorg/data-engineer/main/data/population_by_age.tsv
# Out:
# --2024-09-25 23:33:00--  https://raw.githubusercontent.com/pathwaytipsorg/data-engineer/main/data/population_by_age.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26070 (25K) [text/plain]
# Saving to: ‘population_by_age.tsv’
#
# population_by_age.t 100%[===================>]  25.46K  --.-KB/s    in 0.001s
#
# 2024-09-25 23:33:01 (19.2 MB/s) - ‘population_by_age.tsv’ saved [26070/26070]

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("population_by_age.tsv").getOrCreate()
df = spark.read.csv("population_by_age.tsv", sep = "\t",header=True)
df.show()
# Out:
# +------------------+------+-----+------+------+------+-----+------+------+-----+------+------+------+
# | indic_de,geo\time| 2008 |2009 | 2010 | 2011 | 2012 |2013 | 2014 | 2015 |2016 | 2017 | 2018 | 2019 |
# +------------------+------+-----+------+------+------+-----+------+------+-----+------+------+------+
# |       PC_Y0_14,AD| 14.6 |14.5 | 14.5 | 15.5 | 15.5 |15.5 |    : |    : |   : |    : |    : | 13.9 |
# |       PC_Y0_14,AL| 24.1 |23.3 | 22.5 | 21.6 | 20.7 |20.1 | 19.6 | 19.0 |18.5 | 18.2 | 17.7 | 17.2 |
# |       PC_Y0_14,AM| 19.0 |18.6 | 18.3 |    : |    : |   : |    : | 19.4 |19.6 | 20.0 | 20.2 | 20.2 |
# |       PC_Y0_14,AT| 15.4 |15.1 | 14.9 | 14.7 | 14.6 |14.4 | 14.3 | 14.3 |14.3 | 14.4 | 14.4 | 14.4 |
# |       PC_Y0_14,AZ| 23.2 |22.6 | 22.6 | 22.3 | 22.2 |22.3 | 22.4 | 22.4 |22.5 | 22.6 | 22.6 | 22.4 |
# |       PC_Y0_14,BE| 16.9 |16.9 | 16.9 |17.0 b| 17.0 |17.0 | 17.0 | 17.0 |17.0 | 17.0 | 17.0 | 16.9 |
# ...

# %%
renamed_df = df.toDF(*[c.replace(" ", "_") for c in df.columns])
renamed_df.show()
# Out:
# +------------------+------+-----+------+------+------+-----+------+------+-----+------+------+------+
# | indic_de,geo\time| 2008_|2009_| 2010_| 2011_| 2012_|2013_| 2014_| 2015_|2016_| 2017_| 2018_| 2019_|
# +------------------+------+-----+------+------+------+-----+------+------+-----+------+------+------+
# |       PC_Y0_14,AD| 14.6 |14.5 | 14.5 | 15.5 | 15.5 |15.5 |    : |    : |   : |    : |    : | 13.9 |
# |       PC_Y0_14,AL| 24.1 |23.3 | 22.5 | 21.6 | 20.7 |20.1 | 19.6 | 19.0 |18.5 | 18.2 | 17.7 | 17.2 |
# |       PC_Y0_14,AM| 19.0 |18.6 | 18.3 |    : |    : |   : |    : | 19.4 |19.6 | 20.0 | 20.2 | 20.2 |
# |       PC_Y0_14,AT| 15.4 |15.1 | 14.9 | 14.7 | 14.6 |14.4 | 14.3 | 14.3 |14.3 | 14.4 | 14.4 | 14.4 |
# |       PC_Y0_14,AZ| 23.2 |22.6 | 22.6 | 22.3 | 22.2 |22.3 | 22.4 | 22.4 |22.5 | 22.6 | 22.6 | 22.4 |
# |       PC_Y0_14,BE| 16.9 |16.9 | 16.9 |17.0 b| 17.0 |17.0 | 17.0 | 17.0 |17.0 | 17.0 | 17.0 | 16.9 |
# ...

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 MB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.3-py2.py3-none-any.whl size=317840625 sha256=42968ab73692ea041eb296d9f46be495035f4eb004c53be7d9b8b29c3fedc129
#   Stored in directory: /root/.cache/pip/wheels/1b/3a/92/28b93e2fbfdbb07509ca4d6f50c5e407f48dce4ddbda69a4ab
# Successfully built pyspark
# ...

# %%
renamed_df = df.toDF("indic_de_new,geo\time_new","2008_new","2009_new","2010_new","2011_new","2012_new","2013_new","2014_new","2015_new", "2016_new","2017_new", "2018_new", "2019_new")
renamed_df.show()
# Out:
# +-------------------------+--------+--------+--------+--------+--------+--------+--------+--------+--------+--------+--------+--------+
# |indic_de_new,geo\time_new|2008_new|2009_new|2010_new|2011_new|2012_new|2013_new|2014_new|2015_new|2016_new|2017_new|2018_new|2019_new|
# +-------------------------+--------+--------+--------+--------+--------+--------+--------+--------+--------+--------+--------+--------+
# |              PC_Y0_14,AD|   14.6 |   14.5 |   14.5 |   15.5 |   15.5 |   15.5 |      : |      : |      : |      : |      : |   13.9 |
# |              PC_Y0_14,AL|   24.1 |   23.3 |   22.5 |   21.6 |   20.7 |   20.1 |   19.6 |   19.0 |   18.5 |   18.2 |   17.7 |   17.2 |
# |              PC_Y0_14,AM|   19.0 |   18.6 |   18.3 |      : |      : |      : |      : |   19.4 |   19.6 |   20.0 |   20.2 |   20.2 |
# |              PC_Y0_14,AT|   15.4 |   15.1 |   14.9 |   14.7 |   14.6 |   14.4 |   14.3 |   14.3 |   14.3 |   14.4 |   14.4 |   14.4 |
# ...
